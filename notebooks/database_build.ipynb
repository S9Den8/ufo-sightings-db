# %% [markdown]
# # Inside this notebook, I need to do the following:
#
# - import sql
# - create tables
# - insert cleaned datasets

# %% [markdown]
# this will require: integration into SQLite + table creations and insertrs
